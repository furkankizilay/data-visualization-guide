# %% [markdown]
# # Data Visualization
#
# Data visualization is the graphic representation of data. It involves producing images that communicate relationships among the represented data to viewers. Visualizing data is an esstential part of data analysis and machine learning, but choosing the right type of visualization is often challenging. This guide provides an introduction to popluar data visualization techniques, by presenting sample use cases and providing code examples using Python.
#
# Types of graphs covered:
#
#  - Line Chart
#  - Bar Plot
#  - Histogram and Density Graph
#  - Box Plot
#  - Violin Graph
#  - Scatter Plot
#  - Heatmap
#  - Line Graph (Simple Time Series Chart)
#  - Joint Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Notice this we also include the special command `%matplotlib inline` to ensure that our plots are shown and embedded within the Jupyter notebook itself. Without this command, sometimes plots may show up in pop-up windows.

# %% [markdown]
# ## 1) Line Chart

# %% [markdown]
# The line chart is one of the simplest and most widely used data visualization techniques. A line chart displays information as a series of data points or markers connected by straight lines. You can customize the shape, size, color, and other aesthetic elements of the lines and markers for better visual clarity.

# %%
y = [0.759, 0.81, 0.837, 0.879, 0.91, 0.952]

# %% [markdown]
# We can visualize how the yield of y changes over time using a line chart. To draw a line chart, we can use the `plt.plot` function.

# %%
plt.plot(x);

# %% [markdown]
# ### Customizing the X-axis

# %%
x = [2000, 2001, 2002, 2003, 2004, 2005]
y = [0.759, 0.81, 0.837, 0.879, 0.91, 0.952]

# %%
plt.plot(x, y);

# %% [markdown]
# ### Plotting Multiple Lines

# %%
y = range(2000, 2006)
x1 = [0.759, 0.81, 0.837, 0.879, 0.91, 0.952]
x2 = [0.614, 0.65, 0.789, 0.85, 0.95, 0.987]

# %%
plt.plot(y, x1)
plt.plot(y, x2)

plt.xlabel("Years")
plt.legend(["x1", "x2"])

# %% [markdown]
# ### Example
#
# We'll create a line chart to compare the yields of apples and oranges over 12 years in the imaginary region of Hoenn.

# %%
# Sample data
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# First line
plt.plot(years, apples, 'b-x', linewidth=4, markersize=12, markeredgewidth=4, markeredgecolor='navy')

# Second line
plt.plot(years, oranges, 'r--o', linewidth=4, markersize=12,);

# Title
plt.title('Crop Yields in Hoenn Region')

# Line labels
plt.legend(['Apples', 'Oranges'])

# Axis labels
plt.xlabel('Year'); plt.ylabel('Yield (tons)');

# %% [markdown]
# ## 2) Bar Plot

# %% [markdown]
# Bar charts are quite similar to line charts, i.e., they show a sequence of values. However, a bar is shown for each value, rather than points connected by lines. We can use the `plt.bar` function to draw a bar chart.

# %%
y = range(2000, 2006)
x1 = [0.759, 0.81, 0.837, 0.879, 0.91, 0.952]
x2 = [0.614, 0.65, 0.789, 0.85, 0.95, 0.987]

# %%
plt.bar(y, x1)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# However, since this is a very common use case, the Seaborn library provides a `barplot` function which can automatically compute averages.

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# We can also specify a `hue` argument to compare bar plots side-by-side based on a third feature, e.g., sex.

# %%
sns.barplot(x='total_bill', y='day', hue='sex', data=tips);

# %% [markdown]
# ### Example

# %% [markdown]
# We can use a bar chart visulize the average value of total bill for different days of the week, segmented by sex, for the "tips" dataset.

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips);

# %% [markdown]
# ## 3) Histogram and Density Graph

# %% [markdown]
# A histogram represents the distribution of data by forming bins along the range of the data and then drawing bars to show the number of observations that fall in each bin.

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.distplot(diamonds.price);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Crossmember

# %%
sns.catplot(x = "cut", y = "price", hue = "color", kind = "point", data = diamonds);

# %% [markdown]
# ## 4) Box Plot

# %% [markdown]
# A box plot shows the distribution of data along a single axis, using a "box" and "whiskers". The lower end of the box represents the 1st quartile (i.e. 25% of values are below it), and the upper end of the box represents the 3rd quartile (i.e. 25% of values are above it). The median value is represented via a line inside the box. The "whiskers" represent the minimum & maximum values (sometimes excluding outliers, which are represented as dots).

# %%
tips = sns.load_dataset("tips")

# %%
sns.boxplot(x = tips["total_bill"]);

# %% [markdown]
# ### Crossmember

# %% [markdown]
# Which day we make more money ?

# %%
sns.boxplot(x = "day", y = "total_bill",data = tips);

# %% [markdown]
# Are the number of people and earnings directly proportional?

# %%
sns.boxplot(x = "size", y = "total_bill",data = tips);

# %%
sns.boxplot(x = "day", y = "total_bill", hue = "sex", data = tips);

# %% [markdown]
# ## 5) Violin Graph

# %% [markdown]
# A violin plot is a method of plotting numeric data. It is similar to a box plot, with the addition of a rotated kernel density plot on each side. It is like the intersection of density and boxplot.

# %%
sns.catplot(y = "total_bill",kind = "violin",data = tips);

# %% [markdown]
# ### Crossmember

# %%
sns.catplot(x = "day", y = "total_bill",kind = "violin",data = tips);

# %% [markdown]
# ## 6) Scatterplot

# %% [markdown]
# In a scatter plot, the values of 2 variables are plotted as points on a 2-dimensional grid. Additonally, you can also use a third variable to determine the size or color of the points.

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips);

# %% [markdown]
# ### Crossmember

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "time" ,data = tips);

# %%
sns.scatterplot(x = "total_bill", y = "tip", hue = "day",style = "time" ,data = df);

# %% [markdown]
# ### Showing the linear relationship

# %%
sns.lmplot(x = "total_bill",y="tip",data=tips);

# %%
sns.lmplot(x = "total_bill",y="tip",hue="smoker",data=tips);

# %%
sns.lmplot(x = "total_bill",y="tip",hue="smoker",col = "time",row="sex",data=tips);

# %% [markdown]
# ### Scatterplot Matrix

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# If scatterplot images do not have a dust cloud or structural form, it means that there is no relationship between those two variables.
#
# If the observation points are clustered in different corners in the created scatterplot, there are subgroups that we can not observe with the diagonal trowel.

# %%
sns.pairplot(iris);

# %%
sns.pairplot(iris, hue = "species",markers=["o","s","D"]);

# %% [markdown]
# ### Example

# %% [markdown]
# We can use a scatter plot to visualize sepal length & sepal witdh vary across different species of flowers. The points for each species form a separate cluster, with some overlap between the Versicolor and Virginica species.

# %%
# Create a scatter plot
sns.scatterplot(iris.sepal_length, # X-axis
                iris.sepal_width,  # Y-axis
                hue=iris.species,  # Dot color
                s=100);

# Chart title
plt.title("Flowers");
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## 7) Heatmap

# %% [markdown]
# A heatamp is used to visualize 2-dimensional data like a matrix or a table using colors.
#
# Heatmap is the graph used when we want to see it from a broader perspective in terms of structure, when we want to see long-term data, when there is time series data (year, month) or when we want to see events that repeat at certain periods.
#
# Heatmap is used when we have a multi-class categorical variable at hand, not just in a temporal sense, when we need to visualize it in terms of a particular numeric variable.

# %%
flights = sns.load_dataset("flights").pivot("month", "year", "passengers")

# %%
flights.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
sns.heatmap(flights);

# %%
# Draw a heatmap with the numeric values in each cell
sns.heatmap(flights, 
            fmt="d", 
            annot=True, 
            linewidths=.5, 
            cmap='Blues',
            annot_kws={"fontsize":13});

# %% [markdown]
# ## 8) Line Graph

# %% [markdown]
# It is used to visualize the data produced by machines in data sets with time dependent variables, in scenarios such as the internet of things.

# %%
fmri = sns.load_dataset("fmri")

# %%
sns.lineplot(x = "timepoint",y="signal",data = fmri);

# %% [markdown]
# ### Crossmember

# %%
sns.lineplot(x = "timepoint",y="signal",hue="event",style="event",data = fmri);

# %% [markdown]
# ### Simple Time Series Chart

# %% [markdown]
# You should install pandas_datareader `!pip install pandas_datareader`.

# %%
import pandas_datareader as pr

# %%
df = pr.get_data_yahoo("AAPL",start="2016-01-01", end="2021-01-01")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2016-01-04  26.342501  25.500000  25.652500  26.337500  270597600.0  24.185047
# 2016-01-05  26.462500  25.602501  26.437500  25.677500  223164000.0  23.578989
# 2016-01-06  25.592501  24.967501  25.139999  25.174999  273829600.0  23.117550
# 2016-01-07  25.032499  24.107500  24.670000  24.112499  324377600.0  22.141884
# 2016-01-08  24.777500  24.190001  24.637501  24.240000  283192000.0  22.258966

# %%
df["Close"].plot();

# %%
import pandas as pd

# %%
df["Close"].index = pd.DatetimeIndex(df["Close"].index)

# %%
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 9) Joint Plot

# %% [markdown]
# A Jointplot comprises three plots. Out of the three, one plot displays a bivariate graph which shows how the dependent variable(Y) varies with the independent variable(X). Another plot is placed horizontally at the top of the bivariate graph and it shows the distribution of the independent variable(X).

# %%
data = pd.read_csv("Advertising.csv", index_col="Unnamed: 0")

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
sns.jointplot(x = "TV", y = "Sales", data = data, kind = "reg")

# %%
sns.regplot(data["TV"], data["Sales"], ci = None);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
